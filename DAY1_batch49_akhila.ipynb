# %%
print("hello fayaz thank you for teaching us")
# Out:
# hello fayaz thank you for teaching us

# %%
print("my name is akhila gangapuram")
# Out:
# my name is akhila gangapuram

# %%
print("completed my graduation in TKR college of engineering and technology ")
# Out:
# completed my graduation in TKR college of engineering and technology
